# %% [markdown]
# ![image.png](attachment:1a451750-9a15-4973-9162-4acce6f90b3e.png)

# %% [markdown]
# ![image.png](./rag_explanation.svg)

# %% [markdown]
# ![image.png](attachment:b566b4f9-ac22-4e73-8ec5-a8504a4310f3.png)
